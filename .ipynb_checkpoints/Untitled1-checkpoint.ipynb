# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.flashscore.com/football/england/premier-league-2018-2019/results/"
r = requests.get(url)		# r variable has all the HTML code
htmlContent = r.content	# r returns response so if we want the code we write r.content
# print(htmlContent)		# printing the code

# %%
htmlText = r.text
# print(htmlText)

soup = BeautifulSoup(r.content, 'html.parser')

# print(soup.prettify)
data = soup.find_all("code")
print(data)

print(soup)
# Out:
# []
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=11" http-equiv="X-UA-Compatible"/>
# <title>Premier League 2018/2019 Results - Football/England</title>
# <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://cdn.cookielaw.org/vendorlist/iab2Data.json" rel="preload"/>
# <noscript>
# <meta content="0;URL='https://www.flashscore.mobi/'" http-equiv="refresh"/>
# </noscript>
# <meta content="" name="keywords"/>
# <meta content="Find all of the season's Premier League 2018/2019 results, standings." name="description"/>
# <meta content="Copyright (c) 2006-2022 Livesport s.r.o." name="copyright"/>
# <meta content="index,follow" name="robots"/>
# ...

# %%
soup.find("div.event__time")

# %%
div1= soup.find("div.event__time")
div1

# %%
# print(soup.find_all("div"))

# %%
# for i in soup.find_all("div"):
#     print("#####################")
#     print(i)
#     print("#####################")
